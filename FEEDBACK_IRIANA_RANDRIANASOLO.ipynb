# %% [markdown]
# <a href="https://colab.research.google.com/github/TsouLac/2025_Intro_Python/blob/main/FEEDBACK_IRIANA_RANDRIANASOLO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# The exercice that I found the most challenging is the main exercise of the ***Week 1 Session 2*** which is about creating and manipulating simple data structure. More specifically, the ***"Part IV"*** of the exercise which is about classes

# %% [markdown]
# # Variables:

# %% [markdown]
# - *Planet dict* is a dictionary that maps each planet name to its mass

# %%
planetdict = {'mercury':3.3*10**23,'venus':4.87*10**24,'earth':5.97*10**24,'mars':6.42*10**23,'jupiter':1.9*10**27,'saturn':5.68*10**26,'uranus':8.68*10**25,'nepturn':1.02*10**26}

# %% [markdown]
# - *planet* is a class with two attributes: *name* and *mass*

# %%
class planet:
  def __init__(self,inname=None,inmass=0):
    self.name = inname
    self.mass = inmass
# Create a new instance of that class to represent the Earth (mass=5.97)
earth = planet('earth',5.97)
# Create a new instance of that class to represent Jupiter (mass=1898)
jupiter = planet('jupiter',1898)

# %% [markdown]
# - *is_light* is a custom method to the class planet that returns *True* if the planet is strictly lighter than Jupiter, *False* strictly heavier than Jupiter, and '*same mass!*' if the planet weighs the same as jupiter

# %%
class planet:
  def __init__(self,inname=None,inmass=0):
    self.name = inname
    self.mass = inmass
  def is_light(self):
    if self.mass<planetdict['jupiter']:
      print('True')
    elif self.mass>planetdict['jupiter']:
      print('False')
    else:
      print('same mass!')

# %% [markdown]
# # Question

# %% [markdown]
# The question is to ask Python whether the Earth is lighter than Jupiter, the answer should be true

# %%
planet('earth',planetdict['jupiter']).is_light()
# Out:
# same mass!

# %% [markdown]
# But as shown in the previous code, the Python's answer is *'same mass!'* which I didn't expect. Then, I used the next test which was to compare whether Jupiter is lighter than itself. The answer should be *same mass!* for this one, which is the case

# %%
planet('jupiter', planetdict['jupiter']).is_light()
# Out:
# same mass!

# %% [markdown]
# So I changed the code by replacing *'jupiter* by *earth* just to see how the answer looks like.

# %%
planet('earth',planetdict['earth']).is_light()
# Out:
# True

# %% [markdown]
# I think that planet('*name_of_planet*',planetdict['*name_of_planet*']) creates a new instance of the class palnet with the name *'name_of_planet'* than takes the corresponding mass in the planetdict dictionnary. Then this mass is compared to Jupiter's mass.
# But before this answer, I thought it was used to compare the existing instance with jupiter's values inside the dictionnary.
# Because of this first reasoning I didn't expect the answer for jupiter to be *'same mass!'* because jupiter's mass in the instance is 1898 while the one in the dictionary is 1900. Plus, it doesn't contain the factor 10**27

# %%
planet('Lausanne',planetdict['earth']).is_light()
# Out:
# True

# %% [markdown]
# Also it means that the name of the planet is just to initialize the new variable but doesn't contain any information
